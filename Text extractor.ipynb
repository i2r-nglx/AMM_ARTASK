# %%
import re
import urllib
from bs4 import BeautifulSoup
import os


cwd = os.getcwd()
url = str(cwd).replace('C:','file://').replace('\\','/')+"\A330 Wheel.html"
html = urllib.request.urlopen(url)
soup = BeautifulSoup(html,"lxml")
soup.prettify(formatter=lambda s: s.replace("\xa0", ' '))
data = soup.findAll(text=True)

def visible(element):
    if element.parent.name in ['style', 'script', '[document]', 'head', 'title', 'html', '!DOCTYPE', 'meta']:
        return False
    elif re.match('<!--.*-->', str(element.encode('utf-8'))):
        return False
    #elif re.search("\xa0", element):
        #newtext = element.replace("\xa0", "")
        #element = element.replace(u'\xa0', u' ')
        #print(element)
        #element.replace_with(newtext)
    elif re.match('\n', element):
        return False
    return True
 
result = list(filter(visible, data))
##Replace all "/xa0" (nbsp-non-breaking space)
#if use for i in result => it is just a copy and will not modify the string
for i in range(len(result)):
    result[i] = result[i].replace("\xa0", " ")
#print (result)

# %%
#use nltk to tokenize the content and check if it is a tool, consumable, workzone, or reference info
import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Group text to sections according to the points

# %%
def splitList(ls, text, startInd, numChar):
    subLs = []
    for i in range(len(ls)):
        if ls[i][startInd:numChar] == text:
            sub = []
            while i+1< len(ls) and ls[i+1][startInd:numChar] != text:
                sub.append(ls[i])
                i=i+1
                if i+1 == len(ls) or ls[i+1][startInd:numChar] == text: # last item in result
                    sub.append(ls[i]) 
            subLs.append(sub)
    return subLs

# %%
numSec = 0
taskIndicator = "TASK"
taskList = splitList(result,taskIndicator,0,len(taskIndicator))

#print(taskList[0])
#print(result[-1])

# %%
allText = ' '.join([i.lower() for i in result])
allText
# Out:
# "** on a/c all 32-41-11 pb 401 conf 00  -  wheel - mlg - removal/installation task 32-41-11-000-801-a removal of the mlg wheel warning:  make sure that the safety devices and the warning notices are in position before you start a task on or near:  -  the flight controls  -  the flight control surfaces  -  the landing gear and the related doors  -  components that move.  movement of components can kill or cause injury to persons and/or can cause damage to the equipment.  warning:  let the brakes and the wheels become cool before you go near the landing gear. do not apply a liquid or gas fire extinguisher directly on a hot wheel or brake unit. this could cause an explosion.  warning:  be careful when you use consumable materials. obey the material manufacturer's instructions and your local regulations.      fin :  6500gg  ,  6501gg  ,  6502gg  ,  6503gg  ,  6504gg  ,  6505gg  ,  6506gg  ,  6507gg  1. reason for the job self explanatory 2 job set-up information 2 job set-up information a. fixtures, tools, test and support equipment   reference qty designation no specific 1 adapter - tire inflation/deflation no specific 1 cover - protection no specific ar safety clip - circuit breaker no specific ar standard wheel r and i dolly (98f32401001000 type) no specific 1 warning notice(s)  (460007011)  1 spanner-axle nut, mlg  (98f32401001000)  1 tool-r i wheels  (m47381)  1 guide cone-wheel   b. consumable materials   reference designation (material no.  08baa9 ) non aqueous cleaner-general - - (material no.  14sba1 ) textile-lint free cotton -   c. work zones and access panels   zone/access zone description 731 left main gear 741 right main gear   d. referenced information   reference designation (ref. 07-12-00-582-802-a). jacking of the main landing gear (ref. 29-00-00-863-802-a-01). pressurize the blue hydraulic system with the electric pump (ref. 29-00-00-864-804-a). put the related hydraulic system in the depressurized configuration before maintenance action (ref. 32-00-00-481-801-a). installation of the safety devices on the landing gears (ref. 32-41-15-000-801-a). removal of the mlg hub cap (ref. 32-48-52-000-801-a). removal of the mlg axle equipment carrier (ref. 32-48-52-400-801-a). installation of the mlg axle equipment carrier mlg wheel removal sheet 1 goodrich brakes - inspection of the mlg brake stator slots for enlargement - flow chart honeywell brakes - inspection of the mlg brake stator slots for enlargement - flow chart   3. job set-up subtask 32-41-11-941-051-a a. safety precautions (1) put the  warning notice(s)  in the cockpit, to tell persons not to operate the landing gear.  subtask 32-41-11-860-052-a b. aircraft maintenance configuration (1) install the safety devices on the landing gear   (ref. amm task 32-00-00-481-801)  .  (2) make sure that the green hydraulic system is depressurized  (ref. amm task 29-00-00-864-804)  .  (3) lift the applicable main landing gear (mlg) wheel clear of the ground on jacks   (ref. amm task 07-12-00-582-802)  .  (4) on panel 312vu make sure that the accu press on the triple indicator has sufficient pressure. if necessary, pressurize the blue hydraulic system   (ref. amm task 29-00-00-863-802)  .  (5) on the panel 117vu, put the park brk lever to the on position.  subtask 32-41-11-865-056-a c. get access to the avionics compartment. then open, safety and tag this(these) circuit breaker(s): panel designation fin location  721vu hyd pump g ctl 9jv u09 subtask 32-41-11-010-051-a d. get access (1) remove the hub cap   (ref. amm task 32-41-15-000-801)  .  4. procedure (ref. fig. mlg wheel removal sheet 1)  subtask 32-41-11-020-050-b warning:  decrease the tire pressure to approximately 2 bar (29 psi) before you remove the wheel. this will prevent a possible explosion.  a. removal of the mlg wheel  note:  when you remove the wheel for access, it is not necessary to decrease the tire pressure when these conditions are applicable:  · the wheel and tire are serviceable  · the tire is at its c ...

# %%
fd = nltk.FreqDist(nltk.pos_tag(word_tokenize(allText)))
fd.most_common()
taggedItem = [(wt[0], wt[1],_) for (wt, _) in fd.most_common() if wt[1][0:2] == "NN"]
taggedItem
# Out:
# [('wheel', 'NN', 41),
#  ('ref', 'NN', 33),
#  ('mlg', 'NN', 23),
#  ('inspection', 'NN', 19),
#  ('axle', 'NN', 19),
#  ('brake', 'NN', 17),
#  ('warning', 'NN', 16),
#  ('landing', 'NN', 16),
#  ('slots', 'NNS', 16),
#  ('safety', 'NN', 14),
#  ('equipment', 'NN', 13),
#  ('mlg', 'NNS', 12),
#  ('tire', 'NN', 11),
#  ('nut', 'NN', 11),
#  ('installation', 'NN', 11),
#  ('sheet', 'NN', 11),
#  ('gear', 'NN', 10),
#  ('designation', 'NN', 10),
#  ('panel', 'NN', 10),
#  ('pressure', 'NN', 10),
#  ('removal', 'NN', 9),
#  ('position', 'NN', 9),
#  ('chart', 'NN', 9),
#  ('devices', 'NNS', 8),
#  ('job', 'NN', 8),
#  ('i', 'NN', 8),
#  ('s', 'NN', 8),
#  ('access', 'NN', 8),
#  ('system', 'NN', 8),
#  ('cap', 'NN', 8),
#  ('carrier', 'NN', 8),
#  ('honeywell', 'NN', 8),
#  ('fig', 'NN', 7),
#  ('m.dan', 'NN', 7),
#  ('tachometer', 'NN', 7),
#  ('drive', 'NN', 7),
#  ('figure', 'NN', 7),
#  ('/', 'NNP', 7),
#  ('brakes', 'NNS', 6),
#  ('information', 'NN', 6),
#  ('reference', 'NN', 6),
#  ('maintenance', 'NN', 6),
#  ('action', 'NN', 6),
#  ('gears', 'NNS', 6),
#  ('subtask', 'NN', 6),
#  ('b', 'NN', 6),
#  ('nuts', 'NNS', 6),
#  ('torque', 'NN', 6),
#  ('·', 'NN', 6),
#  ('damage', 'NN', 5),
#  ('wheels', 'NNS', 5),
#  ('fin', 'NN', 5),
#  ('a.', 'NN', 5),
#  ('notice', 'NN', 5),
#  ('m47381', 'NN', 5),
#  ('cone-wheel', 'NN', 5),
#  ('b.', 'NN', 5),
#  ('c.', 'NN', 5),
#  ('pump', 'NN', 5),
#  ('park', 'NN', 5),
#  ('brk', 'NN', 5),
#  ('lever', 'NN', 5),
#  ('cotter', 'NN', 5),
#  ('component', 'NN', 5),
#  ('assembly', 'NN', 5),
#  ('grease', 'NN', 5),
#  ('lbf.ft', 'NN', 5),
#  ('failure', 'NN', 5),
#  ('task', 'NN', 4),
#  ('flight', 'NN', 4),
#  ('components', 'NNS', 4),
#  ('persons', 'NNS', 4),
#  ('materials', 'NNS', 4),
#  ('protection', 'NN', 4),
#  ('circuit', 'NN', 4),
#  ('breaker', 'NN', 4),
#  ('r', 'NN', 4),
#  ('type', 'NN', 4),
#  ('cotton', 'NN', 4),
#  ('blue', 'NN', 4),
#  ('hydraulic', 'NN', 4),
#  ('configuration', 'NN', 4),
#  ('hub', 'NN', 4),
#  ('goodrich', 'NN', 4),
#  ('indicator', 'NN', 4),
#  ('inflation', 'NN', 4),
#  ('pins', 'NNS', 4),
#  ('sleeve', 'NN', 4),
#  ('shaft', 'NN', 4),
#  ('rotors', 'NNS', 4),
#  ('holes', 'NNS', 4),
#  ('fire', 'NN', 3),
#  ('tools', 'NNS', 3),
#  ('support', 'NN', 3),
#  ('d.', 'NN', 3),
#  ('aircraft', 'NN', 3),
#  ('ground', 'NN', 3),
#  ('jacks', 'NNS', 3),
#  ('location', 'NN', 3),
#  ('hyd', 'NN', 3),
#  ('g', 'NN', 3),
#  ('ctl', 'NN', 3),
#  ('bar', 'NN', 3),
#  ('psi', 'NN', 3),
#  ('note', 'NN', 3),
#  ('valve', 'NN', 3),
#  ('c', 'NN', 3),
#  ('washers', 'NNS', 3),
#  ('guide', 'NN', 3),
#  ('carbon', 'NN', 3),
#  ('wrench', 'NN', 3),
#  ('range', 'NN', 3),
#  ('oil', 'NN', 3),
#  ('base', 'NN', 3),
#  ('clay', 'NN', 3),
#  ('parts', 'NNS', 3),
#  ('heat', 'NN', 3),
#  ('report-sheet', 'NN', 3),
#  ('interface', 'NN', 3),
#  ('area', 'NN', 3),
#  ('splines', 'NNS', 3),
#  ('direction', 'NN', 3),
#  ('ipc', 'NN', 3),
#  ('notices', 'NNS', 2),
#  ('control', 'NN', 2),
#  ('doors', 'NNS', 2),
#  ('move', 'NN', 2),
#  ('movement', 'NN', 2),
#  ('injury', 'NN', 2),
#  ('and/or', 'NNS', 2),
#  ('explosion', 'NN', 2),
#  ('manufacturer', 'NN', 2),
#  ('instructions', 'NNS', 2),
#  ('regulations', 'NNS', 2),
#  ('reason', 'NN', 2),
#  ('fixtures', 'NNS', 2),
#  ('test', 'NN', 2),
#  ('qty', 'NN', 2),
#  ('inflation/deflation', 'NN', 2),
#  ('ar', 'NN', 2),
#  ('textile-lint', 'NN', 2),
#  ('work', 'NN', 2),
#  ('zones', 'NNS', 2),
#  ('panels', 'NNS', 2),
#  ('description', 'NN', 2),
#  ('07-12-00-582-802-a', 'NN', 2),
#  ('jacking', 'NN', 2),
#  ('precautions', 'NNS', 2),
#  ('cockpit', 'NN', 2),
#  ('make', 'NN', 2),
#  ('sure', 'NN', 2),
#  ('press', 'NN', 2),
#  ('avionics', 'NNS', 2),
#  ('compartment', 'NN', 2),
#  ('tag', 'NN', 2),
#  ('procedure', 'NN', 2),
#  ('decrease', 'NN', 2),
#  ('tool-r', 'NN', 2),
#  ('bolts', 'NNS', 2),
#  ('use', 'NN', 2),
#  ('dust', 'NN', 2),
#  ('check', 'NN', 2),
#  ('cover', 'NN', 2),
#  ('stator', 'NN', 2),
#  ('chocks', 'NNS', 2),
#  ('quantity', 'NN', 2),
#  ('lbf.in', 'NN', 2),
#  ('pack', 'NN', 2),
#  ('speed', 'NN', 2),
#  ('condition', 'NN', 2),
#  ('clip', 'NN', 2),
#  ('stators', 'NNS', 2),
#  ('broken', 'NN', 2),
#  ('layer', 'NN', 2),
#  ('bolt', 'NN', 2),
#  ('-csn', 'NNP', 2),
#  ('-csn', 'NN', 2),
#  ('**', 'NN', 1),
#  ('pb', 'NN', 1),
#  ('conf', 'NN', 1),
#  ('removal/installation', 'NN', 1),
#  ('liquid', 'NN', 1),
#  ('gas', 'NN', 1),
#  ('unit', 'NN', 1),
#  ('conditions', 'NNS', 1),
#  ('label', 'NN', 1),
#  ('adapter', 'NN', 1),
#  ('gage', 'NN', 1),
#  ('d', 'NN', 1),
#  ('adaptor', 'NN', 1),
#  ('e', 'NN', 1),
#  ('remove', 'NN', 1),
#  ('tool', 'NN', 1),
#  ('interfaces', 'NNS', 1),
#  ('lubricate', 'NN', 1),
#  ('change', 'NN', 1),
#  ('movements', 'NNS', 1),
#  ('fig.item', 'NN', 1),
#  ('e.', 'NN', 1),
#  ('replenishment', 'NN', 1),
#  ('tires', 'NNS', 1),
#  ('b.', 'NNS', 1),
#  ('preparation', 'NN', 1),
#  ('particles', 'NNS', 1),
#  ('marks', 'NNS', 1),
#  ('·', 'NNS', 1),
#  ('spring', 'NN', 1),
#  ('leaks', 'NNS', 1),
#  ('connections', 'NNS', 1),
#  ('pistons', 'NNS', 1),
#  ('fluid', 'NN', 1),
#  ('contamination', 'NN', 1),
#  ('wear', 'NN', 1),
#  ('rotor', 'NN', 1),
#  ('cracks', 'NNS', 1),
#  ('chips', 'NNS', 1),
#  ('areas', 'NNS', 1),
#  ('links', 'NNS', 1),
#  ('rivets', 'NNS', 1),
#  ('rivet', 'NN', 1),
#  ('oxidation', 'NN', 1),
#  ('fault', 'NN', 1),
#  ('disk', 'NN', 1),
#  ('record', 'NN', 1),
#  ('data', 'NNS', 1),
#  ('send', 'NN', 1),
#  ('shield', 'NN', 1),
#  ('steps', 'NNS', 1),
#  ('amount', 'NN', 1),
#  ('bearings', 'NNS', 1),
#  ('seal', 'NN', 1),
#  ('pin', 'NN', 1),
#  ('push', 'NN', 1),
#  ('thread', 'NN', 1),
#  ('align', 'NN', 1),
#  ('heads', 'NNS', 1),
#  ('surface', 'NN', 1),
#  ('washer', 'NN', 1),
#  ('items', 'NNS', 1),
#  ('platform', 'NN', 1),
#  ('flow', 'NN', 1)]

# %%
taggedItem = [(wt[0], wt[1],_) for (wt, _) in fd.most_common() if wt[1][0:2] == "VB"]
taggedItem
# Out:
# [('is', 'VBZ', 27),
#  ('make', 'VB', 20),
#  ('are', 'VBP', 19),
#  ('remove', 'VB', 17),
#  ('brake', 'VBP', 12),
#  ('cause', 'VB', 9),
#  ('put', 'VBD', 9),
#  ('do', 'VBP', 9),
#  ('install', 'VB', 7),
#  ('apply', 'VB', 5),
#  ('subtask', 'VB', 5),
#  ('installed', 'VBN', 5),
#  ('use', 'VBP', 4),
#  ('pressurize', 'VB', 4),
#  ('refer', 'VBP', 4),
#  ('sb', 'VB', 4),
#  ('be', 'VB', 3),
#  ('has', 'VBZ', 3),
#  ('get', 'VB', 3),
#  ('clean', 'VB', 3),
#  ('thickened', 'VBD', 3),
#  ('make', 'VBP', 3),
#  ('damaged', 'VBN', 3),
#  ('turn', 'VB', 3),
#  ('examine', 'VBP', 3),
#  ('missing', 'VBG', 3),
#  ('tighten', 'VB', 3),
#  ('start', 'VBP', 2),
#  ('controls', 'VBZ', 2),
#  ('surfaces', 'VBZ', 2),
#  ('kill', 'VB', 2),
#  ('brake', 'VB', 2),
#  ('self', 'VBD', 2),
#  ('ar', 'VBZ', 2),
#  ('zone/access', 'VBP', 2),
#  ('left', 'VBD', 2),
#  ('referenced', 'VBN', 2),
#  ('put', 'VB', 2),
#  ('related', 'VBN', 2),
#  ('tell', 'VB', 2),
#  ('operate', 'VB', 2),
#  ('depressurized', 'VBN', 2),
#  ('remove', 'VBP', 2),
#  ('burn', 'VB', 2),
#  ('graphited', 'VBN', 2),
#  ('replace', 'VB', 2),
#  ('ref', 'VB', 2),
#  ('·', 'VBP', 2),
#  ('aligned', 'VBN', 2),
#  ('slowly', 'VBP', 2),
#  ('turn', 'VBP', 2),
#  ('brakes', 'VBZ', 2),
#  ('let', 'VB', 1),
#  ('become', 'VBP', 1),
#  ('go', 'VBP', 1),
#  ('do', 'VB', 1),
#  ('lift', 'VB', 1),
#  ('prevent', 'VB', 1),
#  ('decrease', 'VB', 1),
#  ('·', 'VB', 1),
#  ('·', 'VBZ', 1),
#  ('put', 'VBN', 1),
#  ('specifies', 'VBZ', 1),
#  ('attach', 'VBP', 1),
#  ('decrease', 'VBZ', 1),
#  ('shows', 'VBZ', 1),
#  ('discard', 'VB', 1),
#  ('follows', 'VBZ', 1),
#  ('recommended', 'VBN', 1),
#  ('help', 'VB', 1),
#  ('parking', 'VBG', 1),
#  ('applied', 'VBN', 1),
#  ('lifted', 'VBN', 1),
#  ('tagged', 'VBD', 1),
#  ('retained', 'VBD', 1),
#  ('removed', 'VBN', 1),
#  ('clean', 'VBP', 1),
#  ('fretting', 'VBG', 1),
#  ('scratched', 'VB', 1),
#  ('stained', 'VBD', 1),
#  ('corroded', 'VBD', 1),
#  ('sleeve', 'VBP', 1),
#  ('crushed', 'VBN', 1),
#  ('airbus', 'VB', 1),
#  ('align', 'VBZ', 1),
#  ('lubricate', 'VBP', 1),
#  ('touch', 'VB', 1),
#  ('installed', 'VBD', 1),
#  ('safetied', 'VBN', 1),
#  ('align', 'VB', 1),
#  ('were', 'VBD', 1),
#  ('use', 'VB', 1),
#  ('loosen', 'VBD', 1),
#  ('close', 'VB', 1),
#  ('inflate', 'VB', 1)]

# %%
from nltk.tokenize import sent_tokenize
fd = nltk.FreqDist(nltk.pos_tag(word_tokenize(allText)))
fd.most_common()
# Out:
# [(('the', 'DT'), 242),
#  (('(', '('), 225),
#  ((')', ')'), 225),
#  (('.', '.'), 198),
#  (('-', ':'), 62),
#  (('of', 'IN'), 55),
#  (('and', 'CC'), 51),
#  ((',', ','), 48),
#  (('to', 'TO'), 46),
#  (('wheel', 'NN'), 41),
#  (('no', 'DT'), 33),
#  (('ref', 'NN'), 33),
#  ((':', ':'), 32),
#  (('on', 'IN'), 31),
#  (('1', 'CD'), 30),
#  (('a', 'DT'), 29),
#  (('is', 'VBZ'), 27),
#  (('that', 'IN'), 26),
#  (('for', 'IN'), 25),
#  (('mlg', 'NN'), 23),
#  (('sure', 'JJ'), 23),
#  (('in', 'IN'), 21),
#  (('amm', 'JJ'), 21),
#  (('task', 'IN'), 21),
#  (('make', 'VB'), 20),
#  (('are', 'VBP'), 19),
#  (('inspection', 'NN'), 19),
#  (('axle', 'NN'), 19),
#  (('or', 'CC'), 18),
#  (('remove', 'VB'), 17),
#  (('brake', 'NN'), 17),
#  (('warning', 'NN'), 16),
#  (('landing', 'NN'), 16),
#  (('slots', 'NNS'), 16),
#  (('safety', 'NN'), 14),
#  (('you', 'PRP'), 14),
#  (('equipment', 'NN'), 13),
#  (('material', 'JJ'), 13),
#  (('ref', 'JJ'), 13),
#  (('2', 'CD'), 12),
#  (('mlg', 'NNS'), 12),
#  (('brake', 'VBP'), 12),
#  (('stator', 'JJ'), 12),
#  (('enlargement', 'JJ'), 12),
#  (('3', 'CD'), 12),
#  (('there', 'EX'), 12),
#  (('not', 'RB'), 11),
#  (('specific', 'JJ'), 11),
#  (('tire', 'NN'), 11),
#  (('nut', 'NN'), 11),
#  (('installation', 'NN'), 11),
#  (('sheet', 'NN'), 11),
#  (('flow', 'JJ'), 11),
#  (('4', 'CD'), 11),
#  (('if', 'IN'), 11),
#  (('gear', 'NN'), 10),
#  (('designation', 'NN'), 10),
#  (('with', 'IN'), 10),
#  (('panel', 'NN'), 10),
#  (('pressure', 'NN'), 10),
#  (('5', 'CD'), 10),
#  (('removal', 'NN'), 9),
#  (('position', 'NN'), 9),
#  (('cause', 'VB'), 9),
#  (('chart', 'NN'), 9),
#  (('brakes', 'SYM'), 9),
#  (('put', 'VBD'), 9),
#  (('do', 'VBP'), 9),
#  (('devices', 'NNS'), 8),
#  (('an', 'DT'), 8),
#  (('job', 'NN'), 8),
#  (('i', 'NN'), 8),
#  (('98f32401001000', 'CD'), 8),
#  (('s', 'NN'), 8),
#  (('access', 'NN'), 8),
#  (('main', 'JJ'), 8),
#  (('system', 'NN'), 8),
#  (('cap', 'NN'), 8),
#  (('carrier', 'NN'), 8),
#  (('honeywell', 'NN'), 8),
#  (('applicable', 'JJ'), 8),
#  (('axle', 'JJ'), 7),
#  (('install', 'VB'), 7),
#  (('fig', 'NN'), 7),
#  (('it', 'PRP'), 7),
#  (('from', 'IN'), 7),
#  (('6', 'CD'), 7),
#  (('m.dan', 'NN'), 7),
#  (('tachometer', 'NN'), 7),
#  (('drive', 'NN'), 7),
#  (('figure', 'NN'), 7),
#  (('/', 'NNP'), 7),
#  (('before', 'IN'), 6),
#  (('can', 'MD'), 6),
#  (('brakes', 'NNS'), 6),
#  (('this', 'DT'), 6),
#  (('set-up', 'JJ'), 6),
#  (('information', 'NN'), 6),
#  (('reference', 'NN'), 6),
#  (('free', 'JJ'), 6),
#  (('hydraulic', 'JJ'), 6),
#  (('maintenance', 'NN'), 6),
#  (('action', 'NN'), 6),
#  (('gears', 'NNS'), 6),
#  (('subtask', 'NN'), 6),
#  (('b', 'NN'), 6),
#  (('nuts', 'NNS'), 6),
#  (('8', 'CD'), 6),
#  (('torque', 'NN'), 6),
#  (('·', 'NN'), 6),
#  (('damage', 'NN'), 5),
#  (('wheels', 'NNS'), 5),
#  (('apply', 'VB'), 5),
#  (('when', 'WRB'), 5),
#  (('fin', 'NN'), 5),
#  (('a.', 'NN'), 5),
#  (('standard', 'JJ'), 5),
#  (('notice', 'NN'), 5),
#  (('m47381', 'NN'), 5),
#  (('cone-wheel', 'NN'), 5),
#  (('b.', 'NN'), 5),
#  (('c.', 'NN'), 5),
#  (('pump', 'NN'), 5),
#  (('removal', 'JJ'), 5),
#  (('subtask', 'VB'), 5),
#  (('necessary', 'JJ'), 5),
#  (('117vu', 'CD'), 5),
#  (('park', 'NN'), 5),
#  (('brk', 'NN'), 5),
#  (('lever', 'NN'), 5),
#  (('these', 'DT'), 5),
#  (('·', 'IN'), 5),
#  (('7', 'CD'), 5),
#  (('cotter', 'NN'), 5),
#  (('component', 'NN'), 5),
#  (('assembly', 'NN'), 5),
#  (('very', 'RB'), 5),
#  (('grease', 'NN'), 5),
#  (('lbf.ft', 'NN'), 5),
#  (('brake-disk', 'JJ'), 5),
#  (('failure', 'NN'), 5),
#  (('installed', 'VBN'), 5),
#  (('task', 'NN'), 4),
#  (('flight', 'NN'), 4),
#  (('components', 'NNS'), 4),
#  (('persons', 'NNS'), 4),
#  (('use', 'VBP'), 4),
#  (('consumable', 'JJ'), 4),
#  (('materials', 'NNS'), 4),
#  (('protection', 'NN'), 4),
#  (('circuit', 'NN'), 4),
#  (('breaker', 'NN'), 4),
#  (('r', 'NN'), 4),
#  (('dolly', 'RB'), 4),
#  (('type', 'NN'), 4),
#  (('460007011', 'CD'), 4),
#  (('spanner-axle', 'JJ'), 4),
#  (('14sba1', 'CD'), 4),
#  (('cotton', 'NN'), 4),
#  (('gear', 'JJ'), 4),
#  (('pressurize', 'VB'), 4),
#  (('blue', 'NN'), 4),
#  (('hydraulic', 'NN'), 4),
#  (('configuration', 'NN'), 4),
#  (('hub', 'NN'), 4),
#  (('goodrich', 'NN'), 4),
#  (('indicator', 'NN'), 4),
#  (('serviceable', 'JJ'), 4),
#  (('inflation', 'NN'), 4),
#  (('pins', 'NNS'), 4),
#  (('refer', 'VBP'), 4),
#  (('sb', 'VB'), 4),
#  (('must', 'MD'), 4),
#  (('sleeve', 'NN'), 4),
#  (('corrective', 'JJ'), 4),
#  (('shaft', 'NN'), 4),
#  (('correctly', 'RB'), 4),
#  (('rotors', 'NNS'), 4),
#  (('holes', 'NNS'), 4),
#  (('near', 'IN'), 3),
#  (('fire', 'NN'), 3),
#  (('hot', 'JJ'), 3),
#  (('be', 'VB'), 3),
#  (('tools', 'NNS'), 3),
#  (('support', 'NN'), 3),
#  (('d.', 'NN'), 3),
#  (('aircraft', 'NN'), 3),
#  (('ground', 'NN'), 3),
#  (('jacks', 'NNS'), 3),
#  (('07-12-00-582-802', 'JJ'), 3),
#  (('has', 'VBZ'), 3),
#  (('get', 'VB'), 3),
#  (('location', 'NN'), 3),
#  (('721vu', 'CD'), 3),
#  (('hyd', 'NN'), 3),
#  (('g', 'NN'), 3),
#  (('ctl', 'NN'), 3),
#  (('9jv', 'CD'), 3),
#  (('u09', 'JJ'), 3),
#  (('bar', 'NN'), 3),
#  (('psi', 'NN'), 3),
#  (('will', 'MD'), 3),
#  (('possible', 'JJ'), 3),
#  (('note', 'NN'), 3),
#  (('at', 'IN'), 3),
#  (('correct', 'JJ'), 3),
#  (('valve', 'NN'), 3),
#  (('c', 'NN'), 3),
#  (('washers', 'NNS'), 3),
#  (('guide', 'NN'), 3),
#  (('clean', 'VB'), 3),
#  (('carbon', 'NN'), 3),
#  (('9', 'CD'), 3),
#  (('10', 'CD'), 3),
#  (('only', 'RB'), 3),
#  (('small', 'JJ'), 3),
#  (('wrench', 'NN'), 3),
#  (('range', 'NN'), 3),
#  (('03gbb1', 'CD'), 3),
#  (('synthetic', 'JJ'), 3),
#  (('oil', 'NN'), 3),
#  (('base', 'NN'), 3),
#  (('grease-general', 'JJ'), 3),
#  (('purpose', 'JJ'), 3),
#  (('clay', 'NN'), 3),
#  (('thickened', 'VBD'), 3),
#  (('parts', 'NNS'), 3),
#  (('heat', 'NN'), 3),
#  (('report-sheet', 'NN'), 3),
#  (('make', 'VBP'), 3),
#  (('other', 'JJ'), 3),
#  (('interface', 'NN'), 3),
#  (('adjacent', 'JJ'), 3),
#  (('area', 'NN'), 3),
#  (('splines', 'NNS'), 3),
#  (('damaged', 'VBN'), 3),
#  (('turn', 'VB'), 3),
#  (('examine', 'VBP'), 3),
#  (('missing', 'VBG'), 3),
#  (('tighten', 'VB'), 3),
#  (('while', 'IN'), 3),
#  (('same', 'JJ'), 3),
#  (('direction', 'NN'), 3),
#  (('ipc', 'NN'), 3),
#  (('1/2', 'CD'), 3),
#  (('2/2', 'CD'), 3),
#  (('chart', 'JJ'), 3),
#  (('all', 'DT'), 2),
#  (('notices', 'NNS'), 2),
#  (('start', 'VBP'), 2),
#  (('controls', 'VBZ'), 2),
#  (('control', 'NN'), 2),
#  (('surfaces', 'VBZ'), 2),
#  (('related', 'JJ'), 2),
#  (('doors', 'NNS'), 2),
#  (('move', 'NN'), 2),
#  (('movement', 'NN'), 2),
#  (('kill', 'VB'), 2),
#  (('injury', 'NN'), 2),
#  (('and/or', 'NNS'), 2),
#  (('brake', 'VB'), 2),
#  (('could', 'MD'), 2),
#  (('explosion', 'NN'), 2),
#  (('careful', 'JJ'), 2),
#  (('obey', 'IN'), 2),
#  (('manufacturer', 'NN'), 2),
#  (("'s", 'POS'), 2),
#  (('instructions', 'NNS'), 2),
#  (('your', 'PRP$'), 2),
#  (('local', 'JJ'), 2),
#  (('regulations', 'NNS'), 2),
#  (('6500gg', 'CD'), 2),
#  (('6501gg', 'CD'), 2),
#  (('6502gg', 'CD'), 2),
#  (('6503gg', 'CD'), 2),
#  (('6504gg', 'CD'), 2),
#  (('6505gg', 'CD'), 2),
#  (('6506gg', 'CD'), 2),
#  (('6507gg', 'CD'), 2),
#  (('1.', 'CD'), 2),
#  (('reason', 'NN'), 2),
#  (('self', 'VBD'), 2),
#  (('explanatory', 'JJ'), 2),
#  (('fixtures', 'NNS'), 2),
#  (('test', 'NN'), 2),
#  (('qty', 'NN'), 2),
#  (('inflation/deflation', 'NN'), 2),
#  (('cover', 'SYM'), 2),
#  (('ar', 'NN'), 2),
#  (('ar', 'VBZ'), 2),
#  (('tool-r', 'JJ'), 2),
#  (('guide', 'JJ'), 2),
#  (('08baa9', 'CD'), 2),
#  (('aqueous', 'JJ'), 2),
#  (('cleaner-general', 'JJ'), 2),
#  (('textile-lint', 'NN'), 2),
#  (('work', 'NN'), 2),
#  (('zones', 'NNS'), 2),
#  (('panels', 'NNS'), 2),
#  (('zone/access', 'VBP'), 2),
#  (('zone', 'CD'), 2),
#  (('description', 'NN'), 2),
#  (('731', 'CD'), 2),
#  (('left', 'VBD'), 2),
#  (('741', 'CD'), 2),
#  (('right', 'RB'), 2),
#  (('referenced', 'VBN'), 2),
#  (('07-12-00-582-802-a', 'NN'), 2),
#  (('jacking', 'NN'), 2),
#  (('29-00-00-863-802-a-01', 'JJ'), 2),
#  (('electric', 'JJ'), 2),
#  (('29-00-00-864-804-a', 'JJ'), 2),
#  (('put', 'VB'), 2),
#  (('related', 'VBN'), 2),
#  (('depressurized', 'JJ'), 2),
#  (('32-00-00-481-801-a', 'JJ'), 2),
#  (('precautions', 'NNS'), 2),
#  (('cockpit', 'NN'), 2),
#  (('tell', 'VB'), 2),
#  (('operate', 'VB'), 2),
#  (('32-00-00-481-801', 'JJ'), 2),
#  (('green', 'JJ'), 2),
#  (('depressurized', 'VBN'), 2),
#  (('29-00-00-864-804', 'JJ'), 2),
#  (('clear', 'JJ'), 2),
#  (('312vu', 'CD'), 2),
#  (('make', 'NN'), 2),
#  (('sure', 'NN'), 2),
#  (('accu', 'JJ'), 2),
#  (('press', 'NN'), 2),
#  (('triple', 'JJ'), 2),
#  (('sufficient', 'JJ'), 2),
#  (('29-00-00-863-802', 'JJ'), 2),
#  (('subtask', 'JJ'), 2),
#  (('avionics', 'NNS'), 2),
#  (('compartment', 'NN'), 2),
#  (('then', 'RB'), 2),
#  (('open', 'JJ'), 2),
#  (('tag', 'NN'), 2),
#  (('s', 'JJ'), 2),
#  (('procedure', 'NN'), 2),
#  (('decrease', 'NN'), 2),
#  (('remove', 'VBP'), 2),
#  (('a.', 'JJ'), 2),
#  (('its', 'PRP$'), 2),
#  (('2.0', 'CD'), 2),
#  (('29.0075', 'CD'), 2),
#  (('until', 'IN'), 2),
#  (('tool-r', 'NN'), 2),
#  (('bolts', 'NNS'), 2),
#  (('as', 'IN'), 2),
#  (('use', 'NN'), 2),
#  (('textile-lint', 'JJ'), 2),
#  (('dust', 'NN'), 2),
#  (('check', 'NN'), 2),
#  (('cover', 'NN'), 2),
#  (('stator', 'NN'), 2),
#  (('goodrich-messier', 'JJ'), 2),
#  (('32-3238', 'JJ'), 2),
#  (('sb', 'JJ'), 2),
#  (('goodrich', 'JJ'), 2),
#  (('32-3251', 'JJ'), 2),
#  (('chocks', 'NNS'), 2),
#  (('quantity', 'NN'), 2),
#  (('burn', 'VB'), 2),
#  (('between', 'IN'), 2),
#  (('0.4', 'CD'), 2),
#  (('0.45', 'CD'), 2),
#  (('35.40', 'CD'), 2),
#  (('39.82', 'CD'), 2),
#  (('lbf.in', 'NN'), 2),
#  (('30.5', 'CD'), 2),
#  (('224.93', 'CD'), 2),
#  (('54.2', 'CD'), 2),
#  (('399.71', 'CD'), 2),
#  (('03lbb1', 'CD'), 2),
#  (('grease-thread', 'JJ'), 2),
#  (('anti-seize', 'JJ'), 2),
#  (('graphited', 'VBN'), 2),
#  (('petrolatum', 'JJ'), 2),
#  (('32-11-14-20-050', 'JJ'), 2),
#  (('32-11-14-20-060', 'JJ'), 2),
#  (('32-11-14-20-073', 'JJ'), 2),
#  (('32-11-14-20-075', 'JJ'), 2),
#  (('visual', 'JJ'), 2),
#  (('pack', 'NN'), 2),
#  (('wear', 'JJ'), 2),
#  (('speed', 'NN'), 2),
#  (('clean', 'JJ'), 2),
#  (('condition', 'NN'), 2),
#  (('and/or', 'IN'), 2),
#  (('bent', 'JJ'), 2),
#  (('worn', 'JJ'), 2),
#  (('replace', 'VB'), 2),
#  (('ref', 'VB'), 2),
#  (('clip', 'NN'), 2),
#  (('11', 'CD'), 2),
#  (('12', 'CD'), 2),
#  (('stators', 'NNS'), 2),
#  (('·', 'VBP'), 2),
#  (('where', 'WRB'), 2),
#  (('broken', 'NN'), 2),
#  (('13', 'CD'), 2),
#  (('14', 'CD'), 2),
#  (('15', 'CD'), 2),
#  (('16', 'CD'), 2),
#  (('17', 'CD'), 2),
#  (('aligned', 'VBN'), 2),
#  (('off', 'RP'), 2),
#  (('18', 'CD'), 2),
#  (('fully', 'RB'), 2),
#  (('layer', 'NN'), 2),
#  (('slowly', 'VBP'), 2),
#  (('turn', 'VBP'), 2),
#  (('bolt', 'NN'), 2),
#  (('-csn', 'NNP'), 2),
#  (('new', 'JJ'), 2),
#  (('-csn', 'NN'), 2),
#  (('32-41-11-991-01400-00-a', 'JJ'), 2),
#  (('report-sheet', 'JJ'), 2),
#  (('32-41-11-991-01500-00-a', 'JJ'), 2),
#  (('32-41-11-991-01600-00-a', 'JJ'), 2),
#  (('brakes', 'VBZ'), 2),
#  (('**', 'NN'), 1),
#  (('a/c', 'IN'), 1),
#  (('32-41-11', 'JJ'), 1),
#  (('pb', 'NN'), 1),
#  (('401', 'CD'), 1),
#  (('conf', 'NN'), 1),
#  (('00', 'CD'), 1),
#  (('removal/installation', 'NN'), 1),
#  (('32-41-11-000-801-a', 'JJ'), 1),
#  (('let', 'VB'), 1),
#  (('become', 'VBP'), 1),
#  (('cool', 'JJ'), 1),
#  (('go', 'VBP'), 1),
#  (('do', 'VB'), 1),
#  (('liquid', 'NN'), 1),
#  (('gas', 'NN'), 1),
#  (('extinguisher', 'RB'), 1),
#  (('directly', 'RB'), 1),
#  (('unit', 'NN'), 1),
#  (('adapter', 'JJ'), 1),
#  (('clip', 'SYM'), 1),
#  (('non', 'RB'), 1),
#  (('32-41-15-000-801-a', 'JJ'), 1),
#  (('32-48-52-000-801-a', 'JJ'), 1),
#  (('32-48-52-400-801-a', 'JJ'), 1),
#  (('3.', 'CD'), 1),
#  (('32-41-11-941-051-a', 'JJ'), 1),
#  (('32-41-11-860-052-a', 'JJ'), 1),
#  (('lift', 'VB'), 1),
#  (('32-41-11-865-056-a', 'JJ'), 1),
#  (('32-41-11-010-051-a', 'JJ'), 1),
#  (('32-41-15-000-801', 'JJ'), 1),
#  (('4.', 'CD'), 1),
#  (('32-41-11-020-050-b', 'JJ'), 1),
#  (('approximately', 'RB'), 1),
#  (('29', 'CD'), 1),
#  (('prevent', 'VB'), 1),
#  (('decrease', 'VB'), 1),
#  (('conditions', 'NNS'), 1),
#  (('·', 'VB'), 1),
#  (('·', 'VBZ'), 1),
#  (('label', 'NN'), 1),
#  (('put', 'VBN'), 1),
#  (('that', 'WDT'), 1),
#  (('specifies', 'VBZ'), 1),
#  (('attach', 'VBP'), 1),
#  (('adapter', 'NN'), 1),
#  (('decrease', 'VBZ'), 1),
#  (('gage', 'NN'), 1),
#  (('shows', 'VBZ'), 1),
#  (('d', 'NN'), 1),
#  (('adaptor', 'NN'), 1),
#  (('e', 'NN'), 1),
#  (('below', 'IN'), 1),
#  (('remove', 'NN'), 1),
#  (('discard', 'VB'), 1),
#  (('tool', 'NN'), 1),
#  (('mlg', 'JJ'), 1),
#  (('axle-equipment', 'JJ'), 1),
#  (('follows', 'VBZ'), 1),
#  (('32-48-52-000-801', 'JJ'), 1),
#  (('non', '$'), 1),
#  (('interfaces', 'NNS'), 1),
#  (('lubricate', 'NN'), 1),
#  (('32-48-52-400-801', 'JJ'), 1),
#  (('recommended', 'VBN'), 1),
#  (('each', 'DT'), 1),
#  (('change', 'NN'), 1),
#  (('help', 'VB'), 1),
#  (('easy', 'JJ'), 1),
#  (('next', 'JJ'), 1),
#  (('32-4280', 'JJ'), 1),
#  (('32-4288', 'JJ'), 1),
#  (('32-41-11-400-801-a', 'JJ'), 1),
#  (('movements', 'NNS'), 1),
#  (('dangerous', 'JJ'), 1),
#  (('s', 'PRP'), 1),
#  (('expendable', 'JJ'), 1),
#  (('fig.item', 'NN'), 1),
#  (('ipc-csn', 'JJ'), 1),
#  (('washer', 'JJR'), 1),
#  (('e.', 'NN'), 1),
#  (('12-14-32-614-801-a', 'JJ'), 1),
#  (('replenishment', 'NN'), 1),
#  (('tires', 'NNS'), 1),
#  (('32-00-00-081-801-a', 'JJ'), 1),
#  (('32-40-00-210-802-a', 'JJ'), 1),
#  (('parking', 'VBG'), 1),
#  (('applied', 'VBN'), 1),
#  (('32-41-14-400-801-a', 'JJ'), 1),
#  (('32-41-15-400-801-a', 'JJ'), 1),
#  (('32-42-27-000-801-a', 'JJ'), 1),
#  (('32-42-27-400-801-a', 'JJ'), 1),
#  (('32-42-57-000-801-a', 'JJ'), 1),
#  (('32-42-57-400-801-a', 'JJ'), 1),
#  (('5.', 'CD'), 1),
#  (('32-41-11-941-050-a', 'JJ'), 1),
#  (('lifted', 'VBN'), 1),
#  (('32-41-11-865-050-a', 'JJ'), 1),
#  (('b.', 'NNS'), 1),
#  (('safetied', 'JJ'), 1),
#  (('tagged', 'VBD'), 1),
#  (('32-41-11-420-052-a', 'JJ'), 1),
#  (('preparation', 'NN'), 1),
#  (('retained', 'VBD'), 1),
#  (('removed', 'VBN'), 1),
#  (('clean', 'VBP'), 1),
#  (('all', 'PDT'), 1),
#  (('particles', 'NNS'), 1),
#  (('distorted', 'JJ'), 1),
#  (('·', 'JJ'), 1),
#  (('fretting', 'VBG'), 1),
#  (('marks', 'NNS'), 1),
#  (('·', 'MD'), 1),
#  (('scratched', 'VB'), 1),
#  (('stained', 'VBD'), 1),
#  (('corroded', 'VBD'), 1),
#  (('·', 'NNS'), 1),
#  (('·', 'RB'), 1),
#  (('32-42-57-000-801', 'JJ'), 1),
#  (('32-42-57-400-801', 'JJ'), 1),
#  (('sleeve', 'VBP'), 1),
#  (('spring', 'NN'), 1),
#  (('32-41-14-400-801', 'JJ'), 1),
#  (('32-40-00-210-802', 'JJ'), 1),
#  (('leaks', 'NNS'), 1),
#  (('hose', 'JJ'), 1),
#  (('connections', 'NNS'), 1),
#  (('pistons', 'NNS'), 1),
#  (('fluid', 'NN'), 1),
#  (('contamination', 'NN'), 1),
#  (('broken', 'JJ'), 1),
#  (('wear', 'NN'), 1),
#  (('rotor', 'NN'), 1),
#  (('foreign', 'JJ'), 1),
#  (('object', 'JJ'), 1),
#  (('cracks', 'NNS'), 1),
#  (('chips', 'NNS'), 1),
#  (('soft', 'JJ'), 1),
#  (('areas', 'NNS'), 1),
#  (('crushed', 'VBN'), 1),
#  (('links', 'NNS'), 1),
#  (('rivets', 'NNS'), 1),
#  (('rivet', 'NN'), 1),
#  (('oxidation', 'NN'), 1),
#  (('unserviceable', 'JJ'), 1),
#  (('32-42-27-000-801', 'JJ'), 1),
#  (('32-42-27-400-801', 'JJ'), 1),
#  (('fault', 'NN'), 1),
#  (('disk', 'NN'), 1),
#  (('record', 'NN'), 1),
#  (('data', 'NNS'), 1),
#  (('send', 'NN'), 1),
#  (('airbus', 'VB'), 1),
#  (('shield', 'NN'), 1),
#  (('steps', 'NNS'), 1),
#  (('align', 'VBZ'), 1),
#  (('lubricate', 'VBP'), 1),
#  (('amount', 'NN'), 1),
#  (('bearings', 'NNS'), 1),
#  (('touch', 'VB'), 1),
#  (('unwanted', 'JJ'), 1),
#  (('6.', 'CD'), 1),
#  (('pressure-sensor', 'JJ'), 1),
#  (('seal', 'NN'), 1),
#  (('seal', 'JJ'), 1),
#  (('installed', 'VBD'), 1),
#  (('safetied', 'VBN'), 1),
#  (('pin', 'NN'), 1),
#  (('32-41-11-420-050-b', 'JJ'), 1),
#  (('align', 'VB'), 1),
#  (('push', 'NN'), 1),
#  (('as', 'RB'), 1),
#  (('much', 'RB'), 1),
#  (('were', 'VBD'), 1),
#  (('during', 'IN'), 1),
#  (('thin', 'JJ'), 1),
#  (('thread', 'NN'), 1),
#  (('use', 'VB'), 1),
#  (('loosen', 'VBD'), 1),
#  (('slowly', 'RB'), 1),
#  (('two', 'CD'), 1),
#  (('align', 'NN'), 1),
#  (('more', 'JJR'), 1),
#  (('than', 'IN'), 1),
#  (('44.0', 'CD'), 1),
#  (('324.48', 'CD'), 1),
#  (('also', 'RB'), 1),
#  (('heads', 'NNS'), 1),
#  (('outer', 'JJ'), 1),
#  (('surface', 'NN'), 1),
#  (('washer', 'NN'), 1),
#  (('ipc', 'JJ'), 1),
#  (('19', 'CD'), 1),
#  (('20', 'CD'), 1),
#  (('radially', 'RB'), 1),
#  (('around', 'IN'), 1),
#  (('21', 'CD'), 1),
#  (('32-41-11-410-050-a', 'JJ'), 1),
#  (('close', 'JJ'), 1),
#  (('32-41-15-400-801', 'JJ'), 1),
#  (('7.', 'CD'), 1),
#  (('close-up', 'JJ'), 1),
#  (('32-41-11-865-052-a', 'CD'), 1),
#  (('close', 'VB'), 1),
#  (('32-41-11-860-051-a', 'JJ'), 1),
#  (('inflate', 'VB'), 1),
#  (('12-14-32-614-801', 'JJ'), 1),
#  (('lower', 'JJR'), 1),
#  (('32-41-11-942-050-a', 'JJ'), 1),
#  (('32-00-00-081-801', 'JJ'), 1),
#  (('special', 'JJ'), 1),
#  (('items', 'NNS'), 1),
#  (('platform', 'NN'), 1),
#  (('32-41-11-991-00200-00-c', 'JJ'), 1),
#  (('1/1', 'CD'), 1),
#  (('flow', 'NN'), 1)]

# %%
# get sub list from fromText to toText or end of main list
def getSubList(ls, fromText, toText):
    sub = []
    for i in range(len(ls)):
        if ls[i][0:len(fromText)] == fromText:
            while i < len(ls) and ls[i][0:len(toText)] != toText:
                sub.append(ls[i])
                i=i+1
            return sub

# %%
##Warning notices at the start of the task => use AR text to warn (##TODO: parse and beautify it)
Warning = getSubList(taskList[0],"WARNING","1")
#print(Warning)

##item1 = Reason for job (redundant for this case)
item1 = getSubList(taskList[0],"1","2")
#print(item1)

##item2 = Job setup info => Tools and equipments required for the job (can use AR to show the tools that need to be collected and verify **need images of tools)
item2 = getSubList(taskList[0],"2","3")
#print(item2)

##item3 = job set up (pre-job subtasks such as putting warning sign and deflating)
item3 = getSubList(taskList[0],"3","4")
#print(item3)

#item4 = Procedure (list of steps to complete task)
item4 = getSubList(taskList[0],"4","5")
#print(item4)
#print(taskList[0][-1])

# %%
# parse item2 to get list of tools
class tool:
    def __init__(self, name, reference, quantity, attributes, trackable):
        self.name = name
        self.quantity = quantity
        self.trackable = trackable
        self.attributes = attributes #a dictionary of attributes
        self.reference = reference
    def getAttribute(self, attribute_name):
        if attribute_name in self.attributes:
            return self.attributes[attribute_name]
        else:
            print(attribute_name+" is not an attribute of "+ self.name)
    def getAttributeList(self):
        return self.attributes.keys()
    def getName(self):
        return self.name
    def getTrackable(self):
        return self.trackable
    def setAttribute(self,attribute_name, newvalue):
            self.attributes[attribute_name] = newvalue
    
class consumable:
    def __init__(self, name, reference, trackable):
        self.name = name
        self.trackable = trackable
        self.reference = reference
    def getName(self):
        return self.name
    def getTrackable(self):
        return self.trackable
    def setAttribute(self,attribute_name, newvalue):
        self.attributes[attribute_name] = newvalue
    
class workzone:
    def __init__(self, name, reference, trackable):
        self.name = name
        self.trackable = trackable
        self.reference = reference
    def getName(self):
        return self.name
    def getTrackable(self):
        return self.trackable
    def setAttribute(self,attribute_name, newvalue):
        self.attributes[attribute_name] = newvalue

class reference:
    def __init__(self, name, reference, hyperlink):
        self.name = name
        self.hyperlink = hyperlink
        self.reference = reference
    def getName(self):
        return self.name
    def getTrackable(self):
        return self.trackable
    def setAttribute(self,attribute_name, newvalue):
        self.attributes[attribute_name] = newvalue
#task->substask-> steps (action on object to object on params to paramsValue)

# %%
toolsList= []
consumables = []
workzones = []
references = []

# %%
def getNumTag(text,tag):
    tokenized = word_tokenize(text)
    tagged = nltk.pos_tag(tokenized,tagset='universal')
    fd =  nltk.FreqDist(tagged)
    taggedItem = [wt[0] for (wt, _) in fd.most_common() if wt[1] == tag]
    return len(taggedItem)

def getTagged(text):
    tokenized = word_tokenize(text)
    tagged = nltk.pos_tag(tokenized,tagset='universal')
    fd =  nltk.FreqDist(tagged)
    return fd.most_common()

# %%
def isSerialNo(text):
    for i in nltk.pos_tag_sents(word_tokenize(text)):
        fd = nltk.FreqDist(i)
        taggedItem = [x for (wt, x) in fd.most_common() if wt[1] == 'CD']
        if sum(taggedItem)/len(i) >= 0.5 and len(i) > 1:
                return True
    return False

# %%
word_t = word_tokenize(item2[31])
tag = nltk.pos_tag(word_t)
tag = nltk.pos_tag_sents(word_t)
fd = nltk.FreqDist(tag[1])
fd.most_common()
test = item2[65]
print(test)
isSerialNo(test)
# Out:
# Jacking of the Main Landing Gear
# False

# %%
nltk.help.upenn_tagset('PDT')
# Out:
# PDT: pre-determiner
#     all both half many quite such sure this

# %%
def getSetupInfo(section, subheading):
    toolList = []
    consumableList = []
    workzoneList = []
    referenceList = []
    currSection = ""
    sectionID = 0;
    for i in range(len(section)):
        if section[i] == subheading[sectionID]:
            currSection = subheading[sectionID]
            sectionID = (sectionID+1)%len(subheading)
        #condition contains noun, i-1 contain 1 noun or num, i-2 contain 1 noun or num and has than 3 char (not optimal)
        if currSection == subheading[0] and getNumTag(section[i],"NOUN") > 0 and len(word_tokenize(section[i-1])) == 1 and (getNumTag(section[i-1],"NOUN") == 1 or getNumTag(section[i-1],"NUM") == 1) and len(word_tokenize(section[i-2])) >= 2 and (getNumTag(section[i-2],"NOUN") == 1 or getNumTag(section[i-2],"NUM") == 1):
            toolList.append(tool(section[i],section[i-2],section[i-1],{},""))
        if currSection == subheading[1] and getNumTag(section[i],"NOUN") > 0 and len(word_tokenize(section[i-1])) == 1 and getNumTag(section[i-1],".") == 1 and len(word_tokenize(section[i-2])) == 1 and (getNumTag(section[i-2],"NOUN") == 1 or getNumTag(section[i-2],"NUM") == 1):
            consumableList.append(consumable(section[i],section[i-2],""))
        if currSection == subheading[2] and getNumTag(section[i],"NOUN") >= 2 and len(word_tokenize(section[i-1])) == 1 and getNumTag(section[i-1],"NUM") == 1:
            workzoneList.append(workzone(section[i],section[i-1],""))
        if currSection == subheading[3] and getNumTag(section[i],"NOUN") >= 2 and len(word_tokenize(section[i-1])) > 0 and "Ref" in section[i-1]:
            referenceList.append(reference(section[i],section[i-1],""))
        elif currSection == subheading[3] and getNumTag(section[i],"NOUN") >= 4:
            referenceList.append(reference(section[i],"NA",""))
    return toolList, consumableList, workzoneList, referenceList

# %%
toolsList, consumables, workzones, references = getSetupInfo(item2, ["A.","B.","C.","D."])
print("Tool list")
for t in toolsList:
    print (t.name, t.reference)
print("Consumables")
for c in consumables:
    print (c.name, c.reference)
print("Workzone")
for w in workzones:
    print (w.name, w.reference)    
print("References")
for r in references:
    print (r.name, r.reference)
# Out:
# Tool list
# ADAPTER - TIRE INFLATION/DEFLATION No specific
# COVER - PROTECTION No specific
# SAFETY CLIP - CIRCUIT BREAKER No specific
# STANDARD WHEEL R AND I DOLLY (98F32401001000 TYPE) No specific
# WARNING NOTICE(S) No specific
# SPANNER-AXLE NUT, MLG  (460007011)
# TOOL-R I WHEELS  (98F32401001000)
# GUIDE CONE-WHEEL  (M47381)
# Consumables
# Non Aqueous Cleaner-General - - 08BAA9
# Textile-Lint free Cotton - 14SBA1
# Workzone
# LEFT MAIN GEAR 731
# RIGHT MAIN GEAR 741
# References
# Jacking of the Main Landing Gear (Ref. 07-12-00-582-802-A).
# Pressurize the Blue Hydraulic System with the Electric Pump (Ref. 29-00-00-863-802-A-01).
# Put the Related Hydraulic System in the Depressurized Configuration before Maintenance Action (Ref. 29-00-00-864-804-A).
# Installation of the Safety Devices on the Landing Gears (Ref. 32-00-00-481-801-A).
# Removal of the MLG Hub Cap (Ref. 32-41-15-000-801-A).
# Removal of the MLG Axle Equipment Carrier (Ref. 32-48-52-000-801-A).
# Installation of the MLG Axle Equipment Carrier (Ref. 32-48-52-400-801-A).
# MLG Wheel Removal SHEET 1 NA
# Goodrich Brakes - Inspection of the MLG Brake Stator Slots for Enlargement - Flow Chart NA
# Honeywell Brakes - Inspection of the MLG Brake Stator Slots for Enlargement - Flow Chart NA

# %%
# parse item3 to get subtasks to perform job (verification at the end of each subtask)
setUpSubTaskList = splitList(item3, "Subtask",0,len("Subtask"))
print(setUpSubTaskList)
# Out:
# [['Subtask 32-41-11-941-051-A', 'A.', 'Safety Precautions', '(1)', 'Put the ', 'WARNING NOTICE(S)', ' in the cockpit, to tell persons not to operate the landing gear. '], ['Subtask 32-41-11-860-052-A', 'B.', 'Aircraft Maintenance Configuration', '(1)', 'Install the safety devices on the landing gear ', ' (Ref. AMM TASK 32-00-00-481-801) ', '. ', '(2)', 'Make sure that the Green hydraulic system is depressurized', ' (Ref. AMM TASK 29-00-00-864-804) ', '. ', '(3)', 'Lift the applicable Main Landing Gear (MLG) wheel clear of the ground on jacks ', ' (Ref. AMM TASK 07-12-00-582-802) ', '. ', '(4)', 'On panel 312VU make sure that the ACCU PRESS on the triple indicator has sufficient pressure. If necessary, pressurize the Blue hydraulic system ', ' (Ref. AMM TASK 29-00-00-863-802) ', '. ', '(5)', 'On the panel 117VU, put the PARK BRK lever to the ON position. '], ['Subtask 32-41-11-865-056-A', 'C.', 'Get access to the avionics compartment. Then open, safety and tag this(these) circuit breaker(s):', 'PANEL', 'DESIGNATION', 'FIN', 'LOCATION', ' 721VU', 'HYD PUMP G CTL', '9JV', 'U09'], ['Subtask 32-41-11-010-051-A', 'D.', 'Get Access', '(1)', 'Remove the hub cap ', ' (Ref. AMM TASK 32-41-15-000-801) ', '. ']]

# %%
class subTask:
    steps = []
    def __init__(self, name, reference, ind, warning, parent):
        self.parent = parent
        self.name = name
        self.ind = ind
        self.warning = warning
        self.reference = reference
class step:
    target = []
    def __init__(self, description, action, component, tool, preTrackable, postTrackable, parent):
        self.parent = parent
        self.description = description
        self.action = action
        self.component = component
        self.tool = tool
        self.preTrackable =  preTrackable
        self.postTrackable = postTrackable
        
        
class component:
    def __init__(self, name, reference, attributes, trackable):
        self.name = name
        #self.quantity = quantity
        self.trackable = trackable
        self.attributes = attributes #a dictionary of attributes
        self.reference = reference
    def getAttribute(self, attribute_name):
        if attribute_name in self.attributes:
            return self.attributes[attribute_name]
        else:
            print(attribute_name+" is not an attribute of "+ self.name)
    def getAttributeList(self):
        return self.attributes.keys()
    def getName(self):
        return self.name
    def getTrackable(self):
        return self.trackable
    def setAttribute(self,attribute_name, newvalue):
        self.attributes[attribute_name] = newvalue

# %%
suSubTaskList = []
st0 = subTask(setUpSubTaskList[0][2], word_tokenize(setUpSubTaskList[0][0])[1], 0, "", item3[1])

# %%
numStep = 0
description = ""
descriptions = []
for i in setUpSubTaskList[0]:
    if i == '('+str(numStep+1)+')':
        if numStep > 0:
            descriptions.append(description)
        numStep += 1
        description = ""
    elif numStep > 0:
        description += i
descriptions.append(description)
        
nltk.pos_tag(word_tokenize(descriptions[0]))

toolListName = [t.name.lower()  for t in toolsList]
toolListName
# Out:
# ['adapter - tire inflation/deflation',
#  'cover - protection',
#  'safety clip - circuit breaker',
#  'standard wheel r and i dolly (98f32401001000 type)',
#  'warning notice(s)',
#  'spanner-axle nut, mlg',
#  'tool-r i wheels',
#  'guide cone-wheel']

# %%
from nltk.corpus import wordnet
from collections import Counter

def matchTexts(list1, list2, numMatch):
    matchIdx = []
    for idx1, word1 in enumerate(word_tokenize(list1)):
        for idx2, t in enumerate(list2):
            list3 = word_tokenize(t)
            for word2 in list3:
                #print(word2)
                wordFromList1 = wordnet.synsets(word1)
                wordFromList2 = wordnet.synsets(word2)
                if wordFromList1 and wordFromList2:
                    s = wordFromList1[0].wup_similarity(wordFromList2[0])
                    if not s:
                        s = 0.0
                    if s > 0.8:
                        matchIdx.append((idx1,idx2))
    x = Counter([y for (x,y) in matchIdx]).most_common(1)
    idx = [i for (i,j) in matchIdx if j == x[0][0]]
    #print(len(idx), len(word_tokenize(list2[x[0][0]])))
    if x and x[0][1] >= numMatch and len(idx)/len(word_tokenize(list2[x[0][0]])) > 0.5:
        return list2[x[0][0]], idx
    else:
        return "None",[]

# %%
#find tool in description
toolMatch, toolMatchIdx1 = matchTexts(descriptions[0],toolListName,2)        
toolMatch, toolMatchIdx1
# Out:
# ('warning notice(s)', [2, 3, 5])

# %%
#find nearest verb => action
#find nearest noun => component
def findNearestTag(textToSearch, matchIdx, tag):
    token = word_tokenize(textToSearch)
    tagged = (nltk.pos_tag(token))
    for i in range(len(token)):
        #search forward
        if i+matchIdx[0] not in matchIdx and i+matchIdx[0] < len(token):
            if tagged[i+matchIdx[0]][1][0:2] == tag:
                return (tagged[i+matchIdx[0]][0]), i+matchIdx[0]
        #search backword
        if matchIdx[0]-i not in matchIdx and matchIdx[0]-i >= 0:
            if tagged[matchIdx[0]-i][1][0:2] == tag:
                return (tagged[matchIdx[0]-i][0]), matchIdx[0]-i
    return "",-1

# %%
action, actionIdx = findNearestTag(descriptions[0],toolMatchIdx1,"VB")
com, componentIdx = findNearestTag(descriptions[0],toolMatchIdx1,"NN")
#Expand nNoun to contain neighbouring noun
#print (descriptions[0])
steps = []
steps.append(step(descriptions[0], action, com, toolMatch,"","",st0 ))
steps[0].parent.name
# Out:
# 'Safety Precautions'

# %%
ActionsListFile = open("Actions_List", 'r')
ActionsList = [i.replace('\n','') for i in ActionsListFile.readlines()]
#print (ActionsList)
ComponentsListFile = open("Components_List", 'r')
ComponentsList = [i.replace('\n','') for i in ComponentsListFile.readlines()]
#print (ComponentsList)

# %%
#1. find tool 2. find component 3. first verb
def parseSubTaskList(setUpSubTaskList):
    suSubTaskList = []
    toolListName = [t.name  for t in toolsList]
    for i in range(len(setUpSubTaskList)):
        st = subTask(setUpSubTaskList[i][2], word_tokenize(setUpSubTaskList[i][0])[1], i, "", item3[1])
        suSubTaskList.append(st)
        st.steps=[]
        numStep = 0
        description = ""
        descriptions = []
        for j in setUpSubTaskList[i]:
            if j == '('+str(numStep+1)+')':
                if numStep > 0:
                    descriptions.append(description)
                numStep += 1
                description = ""
            elif numStep > 0:
                description += j
        descriptions.append(description)
        if not descriptions[0]:
            descriptions[0] = setUpSubTaskList[i][2]
        for k in range(len(descriptions)):
            sentences = re.split(r'[,.]', descriptions[k].lower())
            actions = []
            components = []
            tools = []
            for sent in sentences:
                action = ""
                component = ""
                tool = ""
                toolMatch, toolMatchIdx = matchTexts(sent.lower(),toolListName,2)
                actionMatch, actionIdx = matchTexts(sent.lower(),ActionsList,1)
                componentMatch, componentIdx = matchTexts(sent.lower(),ComponentsList,1)
                if (not toolMatch == "None") and actionMatch == "None":
                    actionMatch, actionIdx = findNearestTag(sent,[toolMatchIdx[0]],"VB")
                if (not toolMatch == "None") and componentMatch == "None":
                    componentMatch, componentIdx = findNearestTag(sent,[toolMatchIdx[0]],"NN")    
                if not actionMatch == "None":
                    action = actionMatch
                    actions.append(action)
                if not componentMatch == "None":
                    component = componentMatch
                    components.append(component)
                if not toolMatch == "None":
                    tool = toolMatch
                    tools.append(tool)
            st.steps.append(step(descriptions[k], actions, components, tools,"","",st ))
    return suSubTaskList

# %%
sttl = parseSubTaskList(setUpSubTaskList)

# %%
x = 1
y = 1
print(sttl[x].steps[y].description.lower())
print(sttl[x].steps[y].action)
print(sttl[x].steps[y].component)
print(sttl[x].steps[y].tool)
# Out:
# make sure that the green hydraulic system is depressurized (ref. amm task 29-00-00-864-804) .
# ['make sure']
# ['hydraulic system']
# []

# %%
#1. Chunk the sentence
chunkSent = word_tokenize(sttl[x].steps[y].description)
#chunckSent = [nltk.word_tokenize(sent) for sent in chunckSent]
chunkSent = nltk.pos_tag(chunkSent)
grammar = r"""
    NP: {<DT>?<JJ>*<NN|NNP|NNS>+} 
    ACT: {<VB|PDT>}
    PST: {<VBZ><VBN>}
    VP: {<ACT>+<NP>}
    TNP: {<TO><NP>} 
    INP: {<IN><NP>}
    """
cp = nltk.RegexpParser(grammar)
result = cp.parse(chunkSent)
print (result)
# Out:
# (S
#   (NP Make/NNP sure/NN)
#   (INP that/IN (NP the/DT Green/NNP hydraulic/NN system/NN))
#   (PST is/VBZ depressurized/VBN)
#   (/(
#   (NP Ref/NNP)
#   ./.
#   (NP AMM/NNP TASK/NNP)
#   29-00-00-864-804/JJ
#   )/)
#   ./.)

# %%
# for every VP, check if there is an action and component or tool
target=[]
#object to act on
obj = ""
#goal of the object
goal = ""
#end state (in, to, attributes)
state = ""
finalAction = ""
unknown = ""
objIsTool = False
objIsCom = False
hasAction = False
for leaf in result:
    if type(leaf) is nltk.Tree:
        if leaf.label() ==  'VP':
            if leaf[0][0][0].lower() in sttl[x].steps[y].action: #contains action
                n = ' '.join([i[0] for i in leaf[1]])
                if sttl[x].steps[y].tool and re.search(sttl[x].steps[y].tool[0].replace('(S)',''),n): # contain tool (hack: to remove (S))
                    obj = n.replace(leaf[1][0][0],'')
                    objIsTool = True
                else:
                    for com in sttl[x].steps[y].component:
                        if re.search(com, n): #contain component
                            obj = n.replace(leaf[1][0][0],'')
                            objIsCom = True
                    if not objIsCom:
                        obj = n.replace(leaf[1][0][0],'')
                finalAction = leaf[0][0][0].lower()
                if not objIsTool and not objIsCom:
                    unknown = n.replace(leaf[1][0][0],'')
        if leaf.label() == 'INP':
            n = ' '.join([i[0] for i in leaf[1]])
            if sttl[x].steps[y].tool and re.search(sttl[x].steps[y].tool[0].replace('(S)',''),n) and not objIsTool: # contain tool (hack: to remove (S))
                goal = n.replace(leaf[1][0][0],'')
                state = "in"
            else:
                for com in sttl[x].steps[y].component:
                    if re.search(com, n) and not objIsCom: #contain component
                        if objIsTool:
                            goal = n.replace(leaf[1][0][0],'')
                            state = "in"
                        else:
                            obj = n.replace(leaf[1][0][0],'')
                            objIsCom = True
print(unknown)
if objIsCom and goal == "":
    for leaf in result:
        if type(leaf) is nltk.Tree:
            if leaf.label() ==  'PST':
                state = leaf[0][0].lower()
                goal = leaf[1][0].lower()
        if not state and not goal and unknown:
            goal = unknown
            state = "has"
obj = obj[1:] if obj[0] == ' ' and obj else obj
state = state[1:] if state and state[0] == ' ' else state
goal = goal[1:] if goal and goal[0] == ' ' else goal
print (finalAction,obj,state,goal)
# Out:
#  Green hydraulic system is depressurized

# %%
finalCom = component("","",{},"")
finalTool = tool("","",0,{},"")
if objIsTool:
    finalTool = [tool for tool in toolsList if tool.name.replace('(S)','').lower() == obj.lower()]
    finalTool = finalTool[0]
    if goal and state:
        finalTool.setAttribute(state+goal.upper(),False)
        comCand = [com for com in sttl[x].steps[y].component if re.search(goal.lower(), com)]
        if comCand:
            finalCom = component(comCand[0],"",{},"")
if objIsCom:
    finalCom = component(obj,"",{},"")
    if goal and state:
        finalCom.setAttribute(state+goal.upper(),False)

print (finalTool.attributes)
print (finalCom.attributes)

sttl[x].steps[y].action = finalAction if finalAction else sttl[x].steps[y].action[0]
sttl[x].steps[y].component = finalCom if finalCom else sttl[x].steps[y].component
sttl[x].steps[y].tool = finalTool if finalTool else sttl[x].steps[y].tool
print(sttl[x].steps[y].action)
print(sttl[x].steps[y].component.name)
print(sttl[x].steps[y].tool.name)
# Out:
# {}
# {'isDEPRESSURIZED': False}
# make sure
# Green hydraulic system

# %%
print(result[0][0][0])
# Out:
# Make

# %%
# Out:
# (S
#   (VP Put/VB (NP the/DT WARNING/NNP NOTICE/NNP))
#   (/(
#   (NP S/NNP)
#   )/)
#   (INP in/IN (NP the/DT cockpit/NN))
#   ,/,
#   to/TO
#   (VP tell/VB (NP persons/NNS))
#   not/RB
#   to/TO
#   (VP operate/VB (NP the/DT landing/NN gear/NN))
#   ./.)

# %%
# Out:
# ABC

# %%
# Out:
# (S
#   (ABC Make/NNP sure/NN)
#   (INP that/IN (NP the/DT Green/NNP hydraulic/NN system/NN))
#   is/VBZ
#   depressurized/VBN
#   (/(
#   (NP Ref/NNP)
#   ./.
#   (NP AMM/NNP TASK/NNP)
#   29-00-00-864-804/JJ
#   )/)
#   ./.)
